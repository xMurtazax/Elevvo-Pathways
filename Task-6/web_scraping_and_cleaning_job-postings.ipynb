# %%
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# <h2 align='center'>Parsing the raw HTML<h2>

# %%
with open("job_listings.html") as job_listings:
    page = BeautifulSoup(job_listings, 'html.parser')
page
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Job Listings</title>
# <style>
#       body {
#         font-family: Arial, sans-serif;
#         margin: 20px;
#       }
#       .job-listing {
#         border: 1px solid #ccc;
#         padding: 15px;
#         margin-bottom: 10px;
#         border-radius: 5px;
#       }
#       .job-title {
#         font-size: 1.2em;
#         font-weight: bold;
#       }
#       .company,
#       .location,
#       .date,
#       .skills {
#         margin: 5px 0;
#       }
#     </style>
# </head>
# <body>
# <h1>Available Job Listings</h1>
# <div class="job-listing">
# <div class="job-title">Backend Developer</div>
# <div class="company">Company: NextGen</div>
# <div class="location">Location: Lahore, Pakistan</div>
# <div class="date">Posted: 2025-07-30</div>
# <div class="skills">Skills: SQL, Excel, PowerBI</div>
# </div>
# <div class="job-listing">
# <div class="job-title">UI/UX Designer</div>
# <div class="company">Company: NextGen</div>
# <div class="location">Location: Lahore, Pakistan</div>
# <div class="date">Posted: 2025-07-29</div>
# <div class="skills">Skills: Flutter, Dart</div>
# </div>
# <div class="job-listing">
# <div class="job-title">Frontend Developer</div>
# <div class="company">Company: SoftVision</div>
# <div class="location">Location: Karachi, Pakistan</div>
# <div class="date">Posted: 2025-07-28</div>
# <div class="skills">Skills: Selenium, JMeter</div>
# </div>
# <div class="job-listing">
# <div class="job-title">Data Analyst</div>
# <div class="company">Company: NextGen</div>
# <div class="location">Location: Karachi, Pakistan</div>
# <div class="date">Posted: 2025-07-25</div>
# <div class="skills">Skills: Selenium, JMeter</div>
# </div>
# <div class="job-listing">
# <div class="job-title">Data Analyst</div>
# <div class="company">Company: DevMasters</div>
# <div class="location">Location: Karachi, Pakistan</div>
# <div class="date">Posted: 2025-07-23</div>
# <div class="skills">Skills: Figma, Adobe XD, Sketch</div>
# </div>
# <div class="job-listing">
# <div class="job-title">QA Engineer</div>
# <div class="company">Company: DataInsights</div>
# <div class="location">Location: Lahore, Pakistan</div>
# <div class="date">Posted: 2025-07-26</div>
# <div class="skills">Skills: AWS, Docker, Kubernetes, CI/CD</div>
# </div>
# <div class="job-listing">
# <div class="job-title">Machine Learning Engineer</div>
# <div class="company">Company: BetaSoft</div>
# <div class="location">Location: Karachi, Pakistan</div>
# <div class="date">Posted: 2025-07-31</div>
# <div class="skills">Skills: HTML, CSS, JavaScript, React</div>
# </div>
# <div class="job-listing">
# <div class="job-title">Software Engineer</div>
# <div class="company">Company: DevMasters</div>
# <div class="location">Location: Peshawar, Pakistan</div>
# <div class="date">Posted: 2025-07-25</div>
# <div class="skills">Skills: HTML, CSS, JavaScript, React</div>
# </div>
# <div class="job-listing">
# <div class="job-title">DevOps Engineer</div>
# <div class="company">Company: BetaSoft</div>
# <div class="location">Location: Lahore, Pakistan</div>
# <div class="date">Posted: 2025-07-27</div>
# <div class="skills">Skills: Figma, Adobe XD, Sketch</div>
# </div>
# <div class="job-listing">
# <div class="job-title">Full Stack Developer</div>
# <div class="company">Company: DevMasters</div>
# <div class="location">Location: Lahore, Pakistan</div>
# <div class="date">Posted: 2025-07-22</div>
# <div class="skills">Skills: Figma, Adobe XD, Sketch</div>
# </div>
# <div class="job-listing">
# <div class="job-title">Full Stack Developer</div>
# <div class="company">Company: AlphaTech</div>
# <div class="location">Location: Islamabad, Pakistan</div>
# <div class="date">Posted: 2025-07-22</div>
# <div class="skills">Skills: AWS, Docker, Kubernetes, CI/CD</div>
# </div>
# <div class="job-listing">
# <div class="job-title">Machine Learning Engineer</div>
# <div class="company">Company: NextGen</div>
# <div class="location">Location: Peshawar, Pakistan</div>
# <div class="date">Posted: 2025-07-24</div>
# <div class="skills">Skills: Selenium, JMeter</div>
# </div>
# <div class="job-listing">
# <div class="job-title">Software Engineer</div>
# <div class="company">Company: WebWorks</div>
# <div class="location">Location: Karachi, Pakistan</div>
# <div class="date">Posted: 2025-07-26</div>
# <div class="skills">Skills: Python, Django, REST API</div>
# </div>
# <div class="job-listing">
# <div class="job-title">Software Engineer</div>
# <div class="company">Company: BetaSoft</div>
# <div class="location">Location: Karachi, Pakistan</div>
# <div class="date">Posted: 2025-07-22</div>
# <div class="skills">Skills: Figma, Adobe XD, Sketch</div>
# </div>
# <div class="job-listing">
# <div class="job-title">Data Analyst</div>
# <div class="company">Company: DataInsights</div>
# <div class="location">Location: Lahore, Pakistan</div>
# <div class="date">Posted: 2025-07-22</div>
# <div class="skills">Skills: Node.js, Express, MongoDB</div>
# </div>
# <div class="job-listing">
# <div class="job-title">QA Engineer</div>
# <div class="company">Company: DataInsights</div>
# <div class="location">Location: Karachi, Pakistan</div>
# <div class="date">Posted: 2025-07-25</div>
# <div class="skills">Skills: HTML, CSS, JavaScript, React</div>
# </div>
# <div class="job-listing">
# <div class="job-title">Frontend Developer</div>
# <div class="company">Company: CyberSolutions</div>
# <div class="location">Location: Peshawar, Pakistan</div>
# <div class="date">Posted: 2025-07-27</div>
# <div class="skills">Skills: TensorFlow, PyTorch, Scikit-learn</div>
# </div>
# <div class="job-listing">
# <div class="job-title">UI/UX Designer</div>
# <div class="company">Company: BetaSoft</div>
# <div class="location">Location: Karachi, Pakistan</div>
# <div class="date">Posted: 2025-07-30</div>
# <div class="skills">Skills: Java, Spring Boot, Hibernate</div>
# </div>
# <div class="job-listing">
# <div class="job-title">UI/UX Designer</div>
# <div class="company">Company: SoftVision</div>
# <div class="location">Location: Islamabad, Pakistan</div>
# <div class="date">Posted: 2025-07-23</div>
# <div class="skills">Skills: HTML, CSS, JavaScript, React</div>
# </div>
# <div class="job-listing">
# <div class="job-title">DevOps Engineer</div>
# <div class="company">Company: WebWorks</div>
# <div class="location">Location: Islamabad, Pakistan</div>
# <div class="date">Posted: 2025-07-29</div>
# <div class="skills">Skills: Figma, Adobe XD, Sketch</div>
# </div>
# <div class="job-listing">
# <div class="job-title">Data Analyst</div>
# <div class="company">Company: SoftVision</div>
# <div class="location">Location: Peshawar, Pakistan</div>
# <div class="date">Posted: 2025-07-30</div>
# <div class="skills">Skills: Java, Spring Boot, Hibernate</div>
# </div>
# <div class="job-listing">
# <div class="job-title">UI/UX Designer</div>
# <div class="company">Company: CyberSolutions</div>
# <div class="location">Location: Peshawar, Pakistan</div>
# <div class="date">Posted: 2025-07-27</div>
# <div class="skills">Skills: Flutter, Dart</div>
# </div>
# <div class="job-listing">
# <div class="job-title">Machine Learning Engineer</div>
# <div class="company">Company: DevMasters</div>
# <div class="location">Location: Karachi, Pakistan</div>
# <div class="date">Posted: 2025-07-28</div>
# <div class="skills">Skills: AWS, Docker, Kubernetes, CI/CD</div>
# </div>
# <div class="job-listing">
# <div class="job-title">Data Analyst</div>
# <div class="company">Company: Innovatech</div>
# <div class="location">Location: Quetta, Pakistan</div>
# <div class="date">Posted: 2025-07-29</div>
# <div class="skills">Skills: AWS, Docker, Kubernetes, CI/CD</div>
# </div>
# <div class="job-listing">
# <div class="job-title">QA Engineer</div>
# <div class="company">Company: NextGen</div>
# <div class="location">Location: Karachi, Pakistan</div>
# <div class="date">Posted: 2025-07-27</div>
# <div class="skills">Skills: SQL, Excel, PowerBI</div>
# </div>
# <div class="job-listing">
# <div class="job-title">Backend Developer</div>
# <div class="company">Company: SoftVision</div>
# <div class="location">Location: Lahore, Pakistan</div>
# <div class="date">Posted: 2025-07-27</div>
# <div class="skills">Skills: Node.js, Express, MongoDB</div>
# </div>
# <div class="job-listing">
# <div class="job-title">Mobile App Developer</div>
# <div class="company">Company: CloudNet</div>
# <div class="location">Location: Peshawar, Pakistan</div>
# <div class="date">Posted: 2025-07-27</div>
# <div class="skills">Skills: Node.js, Express, MongoDB</div>
# </div>
# <div class="job-listing">
# <div class="job-title">QA Engineer</div>
# <div class="company">Company: SoftVision</div>
# <div class="location">Location: Lahore, Pakistan</div>
# <div class="date">Posted: 2025-07-31</div>
# <div class="skills">Skills: Flutter, Dart</div>
# </div>
# <div class="job-listing">
# <div class="job-title">UI/UX Designer</div>
# <div class="company">Company: CyberSolutions</div>
# <div class="location">Location: Lahore, Pakistan</div>
# <div class="date">Posted: 2025-07-21</div>
# <div class="skills">Skills: TensorFlow, PyTorch, Scikit-learn</div>
# </div>
# <div class="job-listing">
# <div class="job-title">Frontend Developer</div>
# <div class="company">Company: Innovatech</div>
# <div class="location">Location: Islamabad, Pakistan</div>
# <div class="date">Posted: 2025-07-28</div>
# <div class="skills">Skills: SQL, Excel, PowerBI</div>
# </div>
# <div class="job-listing">
# <div class="job-title">Software Engineer</div>
# <div class="company">Company: CloudNet</div>
# <div class="location">Location: Peshawar, Pakistan</div>
# <div class="date">Posted: 2025-07-29</div>
# <div class="skills">Skills: Java, Spring Boot, Hibernate</div>
# </div>
# <div class="job-listing">
# <div class="job-title">QA Engineer</div>
# <div class="company">Company: CloudNet</div>
# <div class="location">Location: Peshawar, Pakistan</div>
# <div class="date">Posted: 2025-07-31</div>
# <div class="skills">Skills: TensorFlow, PyTorch, Scikit-learn</div>
# </div>
# <div class="job-listing">
# <div class="job-title">Full Stack Developer</div>
# <div class="company">Company: WebWorks</div>
# <div class="location">Location: Islamabad, Pakistan</div>
# <div class="date">Posted: 2025-07-27</div>
# <div class="skills">Skills: AWS, Docker, Kubernetes, CI/CD</div>
# </div>
# <div class="job-listing">
# <div class="job-title">Frontend Developer</div>
# <div class="company">Company: CyberSolutions</div>
# <div class="location">Location: Islamabad, Pakistan</div>
# <div class="date">Posted: 2025-07-30</div>
# <div class="skills">Skills: Selenium, JMeter</div>
# </div>
# <div class="job-listing">
# <div class="job-title">DevOps Engineer</div>
# <div class="company">Company: DevMasters</div>
# <div class="location">Location: Lahore, Pakistan</div>
# <div class="date">Posted: 2025-07-24</div>
# <div class="skills">Skills: AWS, Docker, Kubernetes, CI/CD</div>
# </div>
# <div class="job-listing">
# <div class="job-title">Backend Developer</div>
# <div class="company">Company: Innovatech</div>
# <div class="location">Location: Islamabad, Pakistan</div>
# <div class="date">Posted: 2025-07-23</div>
# <div class="skills">Skills: HTML, CSS, JavaScript, React</div>
# </div>
# <div class="job-listing">
# <div class="job-title">Full Stack Developer</div>
# <div class="company">Company: CloudNet</div>
# <div class="location">Location: Peshawar, Pakistan</div>
# <div class="date">Posted: 2025-07-30</div>
# <div class="skills">Skills: Python, Django, REST API</div>
# </div>
# <div class="job-listing">
# <div class="job-title">Full Stack Developer</div>
# <div class="company">Company: CloudNet</div>
# <div class="location">Location: Quetta, Pakistan</div>
# <div class="date">Posted: 2025-07-27</div>
# <div class="skills">Skills: HTML, CSS, JavaScript, React</div>
# </div>
# <div class="job-listing">
# <div class="job-title">Full Stack Developer</div>
# <div class="company">Company: CyberSolutions</div>
# <div class="location">Location: Karachi, Pakistan</div>
# <div class="date">Posted: 2025-07-24</div>
# <div class="skills">Skills: Node.js, Express, MongoDB</div>
# </div>
# <div class="job-listing">
# <div class="job-title">Full Stack Developer</div>
# <div class="company">Company: Innovatech</div>
# <div class="location">Location: Karachi, Pakistan</div>
# <div class="date">Posted: 2025-07-21</div>
# <div class="skills">Skills: Java, Spring Boot, Hibernate</div>
# </div>
# <div class="job-listing">
# <div class="job-title">Backend Developer</div>
# <div class="company">Company: Innovatech</div>
# <div class="location">Location: Lahore, Pakistan</div>
# <div class="date">Posted: 2025-07-28</div>
# <div class="skills">Skills: Figma, Adobe XD, Sketch</div>
# </div>
# <div class="job-listing">
# <div class="job-title">Mobile App Developer</div>
# <div class="company">Company: DataInsights</div>
# <div class="location">Location: Islamabad, Pakistan</div>
# <div class="date">Posted: 2025-07-31</div>
# <div class="skills">Skills: Selenium, JMeter</div>
# </div>
# <div class="job-listing">
# <div class="job-title">Machine Learning Engineer</div>
# <div class="company">Company: BetaSoft</div>
# <div class="location">Location: Peshawar, Pakistan</div>
# <div class="date">Posted: 2025-07-26</div>
# <div class="skills">Skills: Node.js, Express, MongoDB</div>
# </div>
# <div class="job-listing">
# <div class="job-title">QA Engineer</div>
# <div class="company">Company: AlphaTech</div>
# <div class="location">Location: Lahore, Pakistan</div>
# <div class="date">Posted: 2025-07-23</div>
# <div class="skills">Skills: TensorFlow, PyTorch, Scikit-learn</div>
# </div>
# <div class="job-listing">
# <div class="job-title">Backend Developer</div>
# <div class="company">Company: AlphaTech</div>
# <div class="location">Location: Peshawar, Pakistan</div>
# <div class="date">Posted: 2025-07-28</div>
# <div class="skills">Skills: TensorFlow, PyTorch, Scikit-learn</div>
# </div>
# <div class="job-listing">
# <div class="job-title">Software Engineer</div>
# <div class="company">Company: CloudNet</div>
# <div class="location">Location: Karachi, Pakistan</div>
# <div class="date">Posted: 2025-07-21</div>
# <div class="skills">Skills: Node.js, Express, MongoDB</div>
# </div>
# <div class="job-listing">
# <div class="job-title">Software Engineer</div>
# <div class="company">Company: DataInsights</div>
# <div class="location">Location: Quetta, Pakistan</div>
# <div class="date">Posted: 2025-07-26</div>
# <div class="skills">Skills: AWS, Docker, Kubernetes, CI/CD</div>
# </div>
# <div class="job-listing">
# <div class="job-title">DevOps Engineer</div>
# <div class="company">Company: Innovatech</div>
# <div class="location">Location: Peshawar, Pakistan</div>
# <div class="date">Posted: 2025-07-22</div>
# <div class="skills">Skills: Flutter, Dart</div>
# </div>
# <div class="job-listing">
# <div class="job-title">UI/UX Designer</div>
# <div class="company">Company: CloudNet</div>
# <div class="location">Location: Lahore, Pakistan</div>
# <div class="date">Posted: 2025-07-26</div>
# <div class="skills">Skills: TensorFlow, PyTorch, Scikit-learn</div>
# </div>
# <div class="job-listing">
# <div class="job-title">Data Analyst</div>
# <div class="company">Company: DevMasters</div>
# <div class="location">Location: Karachi, Pakistan</div>
# <div class="date">Posted: 2025-07-29</div>
# <div class="skills">Skills: Figma, Adobe XD, Sketch</div>
# </div>
# </body>
# </html>

# %% [markdown]
# <h2 align='center'>Scraping the HTML file<h2>

# %%
job_list = page.find_all(class_ = 'job-listing')
job_list
# Out:
# [<div class="job-listing">
#  <div class="job-title">Backend Developer</div>
#  <div class="company">Company: NextGen</div>
#  <div class="location">Location: Lahore, Pakistan</div>
#  <div class="date">Posted: 2025-07-30</div>
#  <div class="skills">Skills: SQL, Excel, PowerBI</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">UI/UX Designer</div>
#  <div class="company">Company: NextGen</div>
#  <div class="location">Location: Lahore, Pakistan</div>
#  <div class="date">Posted: 2025-07-29</div>
#  <div class="skills">Skills: Flutter, Dart</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">Frontend Developer</div>
#  <div class="company">Company: SoftVision</div>
#  <div class="location">Location: Karachi, Pakistan</div>
#  <div class="date">Posted: 2025-07-28</div>
#  <div class="skills">Skills: Selenium, JMeter</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">Data Analyst</div>
#  <div class="company">Company: NextGen</div>
#  <div class="location">Location: Karachi, Pakistan</div>
#  <div class="date">Posted: 2025-07-25</div>
#  <div class="skills">Skills: Selenium, JMeter</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">Data Analyst</div>
#  <div class="company">Company: DevMasters</div>
#  <div class="location">Location: Karachi, Pakistan</div>
#  <div class="date">Posted: 2025-07-23</div>
#  <div class="skills">Skills: Figma, Adobe XD, Sketch</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">QA Engineer</div>
#  <div class="company">Company: DataInsights</div>
#  <div class="location">Location: Lahore, Pakistan</div>
#  <div class="date">Posted: 2025-07-26</div>
#  <div class="skills">Skills: AWS, Docker, Kubernetes, CI/CD</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">Machine Learning Engineer</div>
#  <div class="company">Company: BetaSoft</div>
#  <div class="location">Location: Karachi, Pakistan</div>
#  <div class="date">Posted: 2025-07-31</div>
#  <div class="skills">Skills: HTML, CSS, JavaScript, React</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">Software Engineer</div>
#  <div class="company">Company: DevMasters</div>
#  <div class="location">Location: Peshawar, Pakistan</div>
#  <div class="date">Posted: 2025-07-25</div>
#  <div class="skills">Skills: HTML, CSS, JavaScript, React</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">DevOps Engineer</div>
#  <div class="company">Company: BetaSoft</div>
#  <div class="location">Location: Lahore, Pakistan</div>
#  <div class="date">Posted: 2025-07-27</div>
#  <div class="skills">Skills: Figma, Adobe XD, Sketch</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">Full Stack Developer</div>
#  <div class="company">Company: DevMasters</div>
#  <div class="location">Location: Lahore, Pakistan</div>
#  <div class="date">Posted: 2025-07-22</div>
#  <div class="skills">Skills: Figma, Adobe XD, Sketch</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">Full Stack Developer</div>
#  <div class="company">Company: AlphaTech</div>
#  <div class="location">Location: Islamabad, Pakistan</div>
#  <div class="date">Posted: 2025-07-22</div>
#  <div class="skills">Skills: AWS, Docker, Kubernetes, CI/CD</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">Machine Learning Engineer</div>
#  <div class="company">Company: NextGen</div>
#  <div class="location">Location: Peshawar, Pakistan</div>
#  <div class="date">Posted: 2025-07-24</div>
#  <div class="skills">Skills: Selenium, JMeter</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">Software Engineer</div>
#  <div class="company">Company: WebWorks</div>
#  <div class="location">Location: Karachi, Pakistan</div>
#  <div class="date">Posted: 2025-07-26</div>
#  <div class="skills">Skills: Python, Django, REST API</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">Software Engineer</div>
#  <div class="company">Company: BetaSoft</div>
#  <div class="location">Location: Karachi, Pakistan</div>
#  <div class="date">Posted: 2025-07-22</div>
#  <div class="skills">Skills: Figma, Adobe XD, Sketch</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">Data Analyst</div>
#  <div class="company">Company: DataInsights</div>
#  <div class="location">Location: Lahore, Pakistan</div>
#  <div class="date">Posted: 2025-07-22</div>
#  <div class="skills">Skills: Node.js, Express, MongoDB</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">QA Engineer</div>
#  <div class="company">Company: DataInsights</div>
#  <div class="location">Location: Karachi, Pakistan</div>
#  <div class="date">Posted: 2025-07-25</div>
#  <div class="skills">Skills: HTML, CSS, JavaScript, React</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">Frontend Developer</div>
#  <div class="company">Company: CyberSolutions</div>
#  <div class="location">Location: Peshawar, Pakistan</div>
#  <div class="date">Posted: 2025-07-27</div>
#  <div class="skills">Skills: TensorFlow, PyTorch, Scikit-learn</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">UI/UX Designer</div>
#  <div class="company">Company: BetaSoft</div>
#  <div class="location">Location: Karachi, Pakistan</div>
#  <div class="date">Posted: 2025-07-30</div>
#  <div class="skills">Skills: Java, Spring Boot, Hibernate</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">UI/UX Designer</div>
#  <div class="company">Company: SoftVision</div>
#  <div class="location">Location: Islamabad, Pakistan</div>
#  <div class="date">Posted: 2025-07-23</div>
#  <div class="skills">Skills: HTML, CSS, JavaScript, React</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">DevOps Engineer</div>
#  <div class="company">Company: WebWorks</div>
#  <div class="location">Location: Islamabad, Pakistan</div>
#  <div class="date">Posted: 2025-07-29</div>
#  <div class="skills">Skills: Figma, Adobe XD, Sketch</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">Data Analyst</div>
#  <div class="company">Company: SoftVision</div>
#  <div class="location">Location: Peshawar, Pakistan</div>
#  <div class="date">Posted: 2025-07-30</div>
#  <div class="skills">Skills: Java, Spring Boot, Hibernate</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">UI/UX Designer</div>
#  <div class="company">Company: CyberSolutions</div>
#  <div class="location">Location: Peshawar, Pakistan</div>
#  <div class="date">Posted: 2025-07-27</div>
#  <div class="skills">Skills: Flutter, Dart</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">Machine Learning Engineer</div>
#  <div class="company">Company: DevMasters</div>
#  <div class="location">Location: Karachi, Pakistan</div>
#  <div class="date">Posted: 2025-07-28</div>
#  <div class="skills">Skills: AWS, Docker, Kubernetes, CI/CD</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">Data Analyst</div>
#  <div class="company">Company: Innovatech</div>
#  <div class="location">Location: Quetta, Pakistan</div>
#  <div class="date">Posted: 2025-07-29</div>
#  <div class="skills">Skills: AWS, Docker, Kubernetes, CI/CD</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">QA Engineer</div>
#  <div class="company">Company: NextGen</div>
#  <div class="location">Location: Karachi, Pakistan</div>
#  <div class="date">Posted: 2025-07-27</div>
#  <div class="skills">Skills: SQL, Excel, PowerBI</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">Backend Developer</div>
#  <div class="company">Company: SoftVision</div>
#  <div class="location">Location: Lahore, Pakistan</div>
#  <div class="date">Posted: 2025-07-27</div>
#  <div class="skills">Skills: Node.js, Express, MongoDB</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">Mobile App Developer</div>
#  <div class="company">Company: CloudNet</div>
#  <div class="location">Location: Peshawar, Pakistan</div>
#  <div class="date">Posted: 2025-07-27</div>
#  <div class="skills">Skills: Node.js, Express, MongoDB</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">QA Engineer</div>
#  <div class="company">Company: SoftVision</div>
#  <div class="location">Location: Lahore, Pakistan</div>
#  <div class="date">Posted: 2025-07-31</div>
#  <div class="skills">Skills: Flutter, Dart</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">UI/UX Designer</div>
#  <div class="company">Company: CyberSolutions</div>
#  <div class="location">Location: Lahore, Pakistan</div>
#  <div class="date">Posted: 2025-07-21</div>
#  <div class="skills">Skills: TensorFlow, PyTorch, Scikit-learn</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">Frontend Developer</div>
#  <div class="company">Company: Innovatech</div>
#  <div class="location">Location: Islamabad, Pakistan</div>
#  <div class="date">Posted: 2025-07-28</div>
#  <div class="skills">Skills: SQL, Excel, PowerBI</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">Software Engineer</div>
#  <div class="company">Company: CloudNet</div>
#  <div class="location">Location: Peshawar, Pakistan</div>
#  <div class="date">Posted: 2025-07-29</div>
#  <div class="skills">Skills: Java, Spring Boot, Hibernate</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">QA Engineer</div>
#  <div class="company">Company: CloudNet</div>
#  <div class="location">Location: Peshawar, Pakistan</div>
#  <div class="date">Posted: 2025-07-31</div>
#  <div class="skills">Skills: TensorFlow, PyTorch, Scikit-learn</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">Full Stack Developer</div>
#  <div class="company">Company: WebWorks</div>
#  <div class="location">Location: Islamabad, Pakistan</div>
#  <div class="date">Posted: 2025-07-27</div>
#  <div class="skills">Skills: AWS, Docker, Kubernetes, CI/CD</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">Frontend Developer</div>
#  <div class="company">Company: CyberSolutions</div>
#  <div class="location">Location: Islamabad, Pakistan</div>
#  <div class="date">Posted: 2025-07-30</div>
#  <div class="skills">Skills: Selenium, JMeter</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">DevOps Engineer</div>
#  <div class="company">Company: DevMasters</div>
#  <div class="location">Location: Lahore, Pakistan</div>
#  <div class="date">Posted: 2025-07-24</div>
#  <div class="skills">Skills: AWS, Docker, Kubernetes, CI/CD</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">Backend Developer</div>
#  <div class="company">Company: Innovatech</div>
#  <div class="location">Location: Islamabad, Pakistan</div>
#  <div class="date">Posted: 2025-07-23</div>
#  <div class="skills">Skills: HTML, CSS, JavaScript, React</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">Full Stack Developer</div>
#  <div class="company">Company: CloudNet</div>
#  <div class="location">Location: Peshawar, Pakistan</div>
#  <div class="date">Posted: 2025-07-30</div>
#  <div class="skills">Skills: Python, Django, REST API</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">Full Stack Developer</div>
#  <div class="company">Company: CloudNet</div>
#  <div class="location">Location: Quetta, Pakistan</div>
#  <div class="date">Posted: 2025-07-27</div>
#  <div class="skills">Skills: HTML, CSS, JavaScript, React</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">Full Stack Developer</div>
#  <div class="company">Company: CyberSolutions</div>
#  <div class="location">Location: Karachi, Pakistan</div>
#  <div class="date">Posted: 2025-07-24</div>
#  <div class="skills">Skills: Node.js, Express, MongoDB</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">Full Stack Developer</div>
#  <div class="company">Company: Innovatech</div>
#  <div class="location">Location: Karachi, Pakistan</div>
#  <div class="date">Posted: 2025-07-21</div>
#  <div class="skills">Skills: Java, Spring Boot, Hibernate</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">Backend Developer</div>
#  <div class="company">Company: Innovatech</div>
#  <div class="location">Location: Lahore, Pakistan</div>
#  <div class="date">Posted: 2025-07-28</div>
#  <div class="skills">Skills: Figma, Adobe XD, Sketch</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">Mobile App Developer</div>
#  <div class="company">Company: DataInsights</div>
#  <div class="location">Location: Islamabad, Pakistan</div>
#  <div class="date">Posted: 2025-07-31</div>
#  <div class="skills">Skills: Selenium, JMeter</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">Machine Learning Engineer</div>
#  <div class="company">Company: BetaSoft</div>
#  <div class="location">Location: Peshawar, Pakistan</div>
#  <div class="date">Posted: 2025-07-26</div>
#  <div class="skills">Skills: Node.js, Express, MongoDB</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">QA Engineer</div>
#  <div class="company">Company: AlphaTech</div>
#  <div class="location">Location: Lahore, Pakistan</div>
#  <div class="date">Posted: 2025-07-23</div>
#  <div class="skills">Skills: TensorFlow, PyTorch, Scikit-learn</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">Backend Developer</div>
#  <div class="company">Company: AlphaTech</div>
#  <div class="location">Location: Peshawar, Pakistan</div>
#  <div class="date">Posted: 2025-07-28</div>
#  <div class="skills">Skills: TensorFlow, PyTorch, Scikit-learn</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">Software Engineer</div>
#  <div class="company">Company: CloudNet</div>
#  <div class="location">Location: Karachi, Pakistan</div>
#  <div class="date">Posted: 2025-07-21</div>
#  <div class="skills">Skills: Node.js, Express, MongoDB</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">Software Engineer</div>
#  <div class="company">Company: DataInsights</div>
#  <div class="location">Location: Quetta, Pakistan</div>
#  <div class="date">Posted: 2025-07-26</div>
#  <div class="skills">Skills: AWS, Docker, Kubernetes, CI/CD</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">DevOps Engineer</div>
#  <div class="company">Company: Innovatech</div>
#  <div class="location">Location: Peshawar, Pakistan</div>
#  <div class="date">Posted: 2025-07-22</div>
#  <div class="skills">Skills: Flutter, Dart</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">UI/UX Designer</div>
#  <div class="company">Company: CloudNet</div>
#  <div class="location">Location: Lahore, Pakistan</div>
#  <div class="date">Posted: 2025-07-26</div>
#  <div class="skills">Skills: TensorFlow, PyTorch, Scikit-learn</div>
#  </div>,
#  <div class="job-listing">
#  <div class="job-title">Data Analyst</div>
#  <div class="company">Company: DevMasters</div>
#  <div class="location">Location: Karachi, Pakistan</div>
#  <div class="date">Posted: 2025-07-29</div>
#  <div class="skills">Skills: Figma, Adobe XD, Sketch</div>
#  </div>]

# %% [markdown]
# <h3 align='center'>Extracting Fields<h3>

# %%
all_fields = []
for job in job_list:
    fields = []
    for field in job:
        if field == '\n':
            continue
        text = field.text.strip()
        class_name = field.get("class")[0]
        if class_name == 'job-title':
            fields.append(text)
        else:
            fields.append(text.split(': ')[-1])
    all_fields.append(fields)
all_fields
# Out:
# [['Backend Developer',
#   'NextGen',
#   'Lahore, Pakistan',
#   '2025-07-30',
#   'SQL, Excel, PowerBI'],
#  ['UI/UX Designer',
#   'NextGen',
#   'Lahore, Pakistan',
#   '2025-07-29',
#   'Flutter, Dart'],
#  ['Frontend Developer',
#   'SoftVision',
#   'Karachi, Pakistan',
#   '2025-07-28',
#   'Selenium, JMeter'],
#  ['Data Analyst',
#   'NextGen',
#   'Karachi, Pakistan',
#   '2025-07-25',
#   'Selenium, JMeter'],
#  ['Data Analyst',
#   'DevMasters',
#   'Karachi, Pakistan',
#   '2025-07-23',
#   'Figma, Adobe XD, Sketch'],
#  ['QA Engineer',
#   'DataInsights',
#   'Lahore, Pakistan',
#   '2025-07-26',
#   'AWS, Docker, Kubernetes, CI/CD'],
#  ['Machine Learning Engineer',
#   'BetaSoft',
#   'Karachi, Pakistan',
#   '2025-07-31',
#   'HTML, CSS, JavaScript, React'],
#  ['Software Engineer',
#   'DevMasters',
#   'Peshawar, Pakistan',
#   '2025-07-25',
#   'HTML, CSS, JavaScript, React'],
#  ['DevOps Engineer',
#   'BetaSoft',
#   'Lahore, Pakistan',
#   '2025-07-27',
#   'Figma, Adobe XD, Sketch'],
#  ['Full Stack Developer',
#   'DevMasters',
#   'Lahore, Pakistan',
#   '2025-07-22',
#   'Figma, Adobe XD, Sketch'],
#  ['Full Stack Developer',
#   'AlphaTech',
#   'Islamabad, Pakistan',
#   '2025-07-22',
#   'AWS, Docker, Kubernetes, CI/CD'],
#  ['Machine Learning Engineer',
#   'NextGen',
#   'Peshawar, Pakistan',
#   '2025-07-24',
#   'Selenium, JMeter'],
#  ['Software Engineer',
#   'WebWorks',
#   'Karachi, Pakistan',
#   '2025-07-26',
#   'Python, Django, REST API'],
#  ['Software Engineer',
#   'BetaSoft',
#   'Karachi, Pakistan',
#   '2025-07-22',
#   'Figma, Adobe XD, Sketch'],
#  ['Data Analyst',
#   'DataInsights',
#   'Lahore, Pakistan',
#   '2025-07-22',
#   'Node.js, Express, MongoDB'],
#  ['QA Engineer',
#   'DataInsights',
#   'Karachi, Pakistan',
#   '2025-07-25',
#   'HTML, CSS, JavaScript, React'],
#  ['Frontend Developer',
#   'CyberSolutions',
#   'Peshawar, Pakistan',
#   '2025-07-27',
#   'TensorFlow, PyTorch, Scikit-learn'],
#  ['UI/UX Designer',
#   'BetaSoft',
#   'Karachi, Pakistan',
#   '2025-07-30',
#   'Java, Spring Boot, Hibernate'],
#  ['UI/UX Designer',
#   'SoftVision',
#   'Islamabad, Pakistan',
#   '2025-07-23',
#   'HTML, CSS, JavaScript, React'],
#  ['DevOps Engineer',
#   'WebWorks',
#   'Islamabad, Pakistan',
#   '2025-07-29',
#   'Figma, Adobe XD, Sketch'],
#  ['Data Analyst',
#   'SoftVision',
#   'Peshawar, Pakistan',
#   '2025-07-30',
#   'Java, Spring Boot, Hibernate'],
#  ['UI/UX Designer',
#   'CyberSolutions',
#   'Peshawar, Pakistan',
#   '2025-07-27',
#   'Flutter, Dart'],
#  ['Machine Learning Engineer',
#   'DevMasters',
#   'Karachi, Pakistan',
#   '2025-07-28',
#   'AWS, Docker, Kubernetes, CI/CD'],
#  ['Data Analyst',
#   'Innovatech',
#   'Quetta, Pakistan',
#   '2025-07-29',
#   'AWS, Docker, Kubernetes, CI/CD'],
#  ['QA Engineer',
#   'NextGen',
#   'Karachi, Pakistan',
#   '2025-07-27',
#   'SQL, Excel, PowerBI'],
#  ['Backend Developer',
#   'SoftVision',
#   'Lahore, Pakistan',
#   '2025-07-27',
#   'Node.js, Express, MongoDB'],
#  ['Mobile App Developer',
#   'CloudNet',
#   'Peshawar, Pakistan',
#   '2025-07-27',
#   'Node.js, Express, MongoDB'],
#  ['QA Engineer',
#   'SoftVision',
#   'Lahore, Pakistan',
#   '2025-07-31',
#   'Flutter, Dart'],
#  ['UI/UX Designer',
#   'CyberSolutions',
#   'Lahore, Pakistan',
#   '2025-07-21',
#   'TensorFlow, PyTorch, Scikit-learn'],
#  ['Frontend Developer',
#   'Innovatech',
#   'Islamabad, Pakistan',
#   '2025-07-28',
#   'SQL, Excel, PowerBI'],
#  ['Software Engineer',
#   'CloudNet',
#   'Peshawar, Pakistan',
#   '2025-07-29',
#   'Java, Spring Boot, Hibernate'],
#  ['QA Engineer',
#   'CloudNet',
#   'Peshawar, Pakistan',
#   '2025-07-31',
#   'TensorFlow, PyTorch, Scikit-learn'],
#  ['Full Stack Developer',
#   'WebWorks',
#   'Islamabad, Pakistan',
#   '2025-07-27',
#   'AWS, Docker, Kubernetes, CI/CD'],
#  ['Frontend Developer',
#   'CyberSolutions',
#   'Islamabad, Pakistan',
#   '2025-07-30',
#   'Selenium, JMeter'],
#  ['DevOps Engineer',
#   'DevMasters',
#   'Lahore, Pakistan',
#   '2025-07-24',
#   'AWS, Docker, Kubernetes, CI/CD'],
#  ['Backend Developer',
#   'Innovatech',
#   'Islamabad, Pakistan',
#   '2025-07-23',
#   'HTML, CSS, JavaScript, React'],
#  ['Full Stack Developer',
#   'CloudNet',
#   'Peshawar, Pakistan',
#   '2025-07-30',
#   'Python, Django, REST API'],
#  ['Full Stack Developer',
#   'CloudNet',
#   'Quetta, Pakistan',
#   '2025-07-27',
#   'HTML, CSS, JavaScript, React'],
#  ['Full Stack Developer',
#   'CyberSolutions',
#   'Karachi, Pakistan',
#   '2025-07-24',
#   'Node.js, Express, MongoDB'],
#  ['Full Stack Developer',
#   'Innovatech',
#   'Karachi, Pakistan',
#   '2025-07-21',
#   'Java, Spring Boot, Hibernate'],
#  ['Backend Developer',
#   'Innovatech',
#   'Lahore, Pakistan',
#   '2025-07-28',
#   'Figma, Adobe XD, Sketch'],
#  ['Mobile App Developer',
#   'DataInsights',
#   'Islamabad, Pakistan',
#   '2025-07-31',
#   'Selenium, JMeter'],
#  ['Machine Learning Engineer',
#   'BetaSoft',
#   'Peshawar, Pakistan',
#   '2025-07-26',
#   'Node.js, Express, MongoDB'],
#  ['QA Engineer',
#   'AlphaTech',
#   'Lahore, Pakistan',
#   '2025-07-23',
#   'TensorFlow, PyTorch, Scikit-learn'],
#  ['Backend Developer',
#   'AlphaTech',
#   'Peshawar, Pakistan',
#   '2025-07-28',
#   'TensorFlow, PyTorch, Scikit-learn'],
#  ['Software Engineer',
#   'CloudNet',
#   'Karachi, Pakistan',
#   '2025-07-21',
#   'Node.js, Express, MongoDB'],
#  ['Software Engineer',
#   'DataInsights',
#   'Quetta, Pakistan',
#   '2025-07-26',
#   'AWS, Docker, Kubernetes, CI/CD'],
#  ['DevOps Engineer',
#   'Innovatech',
#   'Peshawar, Pakistan',
#   '2025-07-22',
#   'Flutter, Dart'],
#  ['UI/UX Designer',
#   'CloudNet',
#   'Lahore, Pakistan',
#   '2025-07-26',
#   'TensorFlow, PyTorch, Scikit-learn'],
#  ['Data Analyst',
#   'DevMasters',
#   'Karachi, Pakistan',
#   '2025-07-29',
#   'Figma, Adobe XD, Sketch']]

# %%
df = pd.DataFrame(columns=['Job title', 'Company', 'Location', 'Posted date', 'Skills'], data = all_fields)

# %% [markdown]
# <h2 align='center'>Text Cleaning<h2>

# %% [markdown]
# ### Splitting Location into City and Country

# %%
df[['City', 'Country']] = df['Location'].str.split(', ', expand=True)

# %% [markdown]
# ### Dropping the location column

# %%
df.drop(columns=['Location'], inplace=True)

# %% [markdown]
# ### Splitting Skills column into list

# %%
df['Skills'] = df['Skills'].apply(lambda x: [skill for skill in x.split(', ')])

# %%
df.to_csv('job_listings.csv', index=False)
